# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#read data
data = pd.read_csv('kc_house_data.csv')
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
#description de données
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
#découvrir les missing valeus
data.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
#découvrir les missing valeus
data.isnull().sum().sum()
# Out:
# 0

# %%
#suprissions des colonnes que n'allons pas besoin
data.drop(columns = ['id', 'zipcode', 'lat', 'long', 'date'], inplace = True)

# %%
data.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'sqft_living15',
#        'sqft_lot15'],
#       dtype='object')

# %%
#totale lignes et colones
data.shape
# Out:
# (21613, 16)

# %%
# Check the data types of each column
print(data.dtypes)
# Out:
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
data.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
#    sqft_living15  sqft_lot15
# ...

# %%
dl = data.copy()
dl.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
#    sqft_living15  sqft_lot15
# ...

# %%
import seaborn as sns

#etude de la correlation
matrice_corr = data.corr().round(1)
sns.heatmap(data=matrice_corr, annot=True)
# Out:
# <Axes: >

# %%
from sklearn.feature_selection import SelectKBest, chi2
label = data['price']
feature = data.drop("price", axis=1)
selector = SelectKBest(chi2, k=5)
selector.fit_transform(feature, label)
# Out:
# array([[ 1180.,  5650.,  1180.,     0.,  5650.],
#        [ 2570.,  7242.,  2170.,  1991.,  7639.],
#        [  770., 10000.,   770.,     0.,  8062.],
#        ...,
#        [ 1020.,  1350.,  1020.,     0.,  2007.],
#        [ 1600.,  2388.,  1600.,     0.,  1287.],
#        [ 1020.,  1076.,  1020.,     0.,  1357.]])

# %%
selector.get_support()
# Out:
# array([False, False,  True,  True, False, False, False, False, False,
#         True, False, False,  True, False,  True])

# %%
from sklearn.preprocessing import StandardScaler,PolynomialFeatures

# Scale and plot the features against price (target) using the MinMax scaler (Normalization)
stan_scaler = StandardScaler()
col_name = dl.drop('price', axis = 1).columns[:]
x = dl.loc[:, col_name]
y = dl['price']

# Normalizing x
x = pd.DataFrame(data = stan_scaler.fit_transform(x), columns = col_name)

# Examine the normalized data
print(dl.head())
x.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
#    sqft_living15  sqft_lot15
# ...

# %%
y_data = dl['price']

x_data=dl.drop('price',axis=1)

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.15, random_state=1)


print("number of test samples :", x_test.shape[0])
print("number of training samples:",x_train.shape[0])

model=LinearRegression()

model.fit(x_train[['sqft_living']], y_train)
predicted=model.predict(x_test[['sqft_living']]) #testing our model’s performance
print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
model.score(x_test[['sqft_living']], y_test)
# Out:
# number of test samples : 3242
# number of training samples: 18371
# MSE 74744588930.51276
# R squared 0.4910058627910614
# 0.4910058627910614

# %%
fig, axs = plt.subplots(ncols = 3, nrows = 3, figsize = (20, 20))
sns.regplot(y = dl['price'], x = x_data['sqft_living'], ax = axs[0, 2])
plt.tight_layout()

# %%
y_data = dl['price']

x_data=dl.drop('price',axis=1)

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.15, random_state=1)


print("number of test samples :", x_test.shape[0])
print("number of training samples:",x_train.shape[0])

model=LinearRegression()

model.fit(x_train, y_train)
predicted=model.predict(x_test) #testing our model’s performance
print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
model.score(x_test, y_test)
# Out:
# number of test samples : 3242
# number of training samples: 18371
# MSE 50803341663.01782
# R squared 0.654040467315454
# 0.654040467315454

# %%
fig, axs = plt.subplots(ncols = 3, nrows = 3, figsize = (20, 20))
sns.regplot(y = dl['price'], x = x_data['bathrooms'], ax = axs[0, 0])
sns.regplot(y = dl['price'], x = x_data['bedrooms'], ax = axs[0, 1])
sns.regplot(y = dl['price'], x = x_data['sqft_living'], ax = axs[0, 2])
sns.regplot(y = dl['price'], x = x_data['sqft_above'], ax = axs[1, 0])
sns.regplot(y = dl['price'], x = x_data['floors'], ax = axs[1, 1])
sns.regplot(y = dl['price'], x = x_data['yr_built'], ax = axs[1, 2])
sns.regplot(y = dl['price'], x = x_data['waterfront'], ax = axs[2, 0])
sns.regplot(y = dl['price'], x = x_data['grade'], ax = axs[2, 1])
sns.regplot(y = dl['price'], x = x_data['sqft_living15'], ax = axs[2, 2])
plt.tight_layout()

# %%
df = data.copy()
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
#    sqft_living15  sqft_lot15
# ...

# %%
#extract x and y from our data
x2=df[["sqft_living","grade", 'sqft_above', 'sqft_living15']]  #we have more than one input
y2=df["price"].values
x_train,x_test,y_train,y_test=train_test_split(x2,y2,test_size=0.35,random_state=40) #splitting data with test size of 35%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (14048, 4)
# (7565, 4)
# (14048,)
# (7565,)

# %%
#entrainement du modèle
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics
# normalisation
from sklearn.compose import make_column_transformer
transformer = make_column_transformer((StandardScaler(), ['sqft_living','grade','sqft_above', 'sqft_living15']) )
transformer.fit_transform(data)
# Out:
# array([[-0.97983502, -0.55883575, -0.73470764, -0.9433552 ],
#        [ 0.53363434, -0.55883575,  0.46084084, -0.43268619],
#        [-1.42625404, -1.40958711, -1.22983377,  1.07013975],
#        ...,
#        [-1.15404732, -0.55883575, -0.92792759, -1.41025258],
#        [-0.52252773,  0.29191561, -0.22750526, -0.8412214 ],
#        [-1.15404732, -0.55883575, -0.92792759, -1.41025258]])

# %%
model=LinearRegression() #build linear regression model
model.fit(x_train,y_train) #fitting the training data
predicted1=model.predict(x_test) #testing our model’s performance
print("MSE", mean_squared_error(y_test,predicted1))
print("R squared", metrics.r2_score(y_test,predicted1))
model.score(x2, y2)
# Out:
# MSE 56391021662.118774
# R squared 0.5514466329799553
# 0.5418460581497357

# %%
fig, axs = plt.subplots(ncols = 3, nrows = 3, figsize = (20, 20))
sns.regplot(y = df['price'], x = x2['sqft_living'], ax = axs[0, 2])
sns.regplot(y = df['price'], x = x2['grade'], ax = axs[2, 1])
sns.regplot(y = df['price'], x = x2['sqft_above'], ax = axs[1, 0])
sns.regplot(y = df['price'], x = x2['sqft_living15'], ax = axs[2, 2])
plt.tight_layout()

# %%
x3=df[["sqft_living"]].values.reshape(-1,1) #we have one input
y3=df["price"].values

x_train, x_test, y_train, y_test = train_test_split(x3, y3, test_size=0.35, random_state=40)  #splitting data
lg=LinearRegression()
poly=PolynomialFeatures(degree=2)

x_train_fit = poly.fit_transform(x_train) #transforming our input data
lg.fit(x_train_fit, y_train)
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)

print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
# Out:
# MSE:  57753648354.73153
# R squared:  0.5406078367860316

# %%
plt.scatter(x3, y3, color="r")
plt.title("Linear regression")
plt.ylabel("price")
plt.xlabel("features")
plt.plot(x3, lg.predict(poly.fit_transform(x3)), color="k")
